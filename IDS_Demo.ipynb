# %% [markdown]
# # 🛡️ Intrusion Detection System — Demo Notebook
# **Student:** Vishrudh N | **Roll No:** 727823TUCY054

# %%
# Run the full IDS tool
exec(open('tool_main.py').read())

# %% [markdown]
# ## Test Case 1 — Port Scan Detection
# Source IP probes more than 5 ports → triggers alert.

# %%
detect_port_scan(SIMULATED_LOGS['port_scan'])

# %% [markdown]
# ## Test Case 2 — Brute Force Detection
# More than 4 failed logins from same IP → triggers alert.

# %%
detect_brute_force(SIMULATED_LOGS['brute_force'])

# %% [markdown]
# ## Test Case 3 — DoS Attack Detection
# More than 10 requests from same IP → triggers alert.

# %%
detect_dos(SIMULATED_LOGS['dos'])

# %% [markdown]
# ## Summary

# %%
print_summary()
